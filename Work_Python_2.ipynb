# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('DZ_6.csv', sep = ',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   expence_last_2month  8 non-null      float64
#  1   expence_last_month   8 non-null      float64
#  2   expence_this_month   8 non-null      float64
#  3   expence_next_month   8 non-null      float64
# dtypes: float64(4)
# memory usage: 384.0 bytes

# %%
df
# Out:
#    expence_last_2month  ...  expence_next_month
# 0              21000.0  ...             18000.0
# 1              19000.0  ...             19000.0
# 2              14000.0  ...             17000.0
# 3              23000.0  ...             19000.0
# 4              18000.0  ...             16000.0
# 5              16500.0  ...             15300.0
# 6              18900.0  ...             21000.0
# 7              21900.0  ...             18000.0
#
# [8 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['expence_last_2month', 'expence_last_month', 'expence_this_month',
#        'expence_next_month'],
#       dtype='object')

# %%
X = df[['expence_last_2month', 'expence_last_month', 'expence_this_month']]
y = df['expence_next_month']

# %%
X
# Out:
#    expence_last_2month  expence_last_month  expence_this_month
# 0              21000.0             20900.0             14900.0
# 1              19000.0             15800.0             16200.0
# 2              14000.0             14800.0             18600.0
# 3              23000.0             17000.0             15800.0
# 4              18000.0             18900.0             23000.0
# 5              16500.0             17300.0             21000.0
# 6              18900.0             17000.0             18900.0
# 7              21900.0             18900.0             17000.0

# %%
y
# Out:
# 0    18000.0
# 1    19000.0
# 2    17000.0
# 3    19000.0
# 4    16000.0
# 5    15300.0
# 6    21000.0
# 7    18000.0
# Name: expence_next_month, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#    expence_last_2month  expence_last_month  expence_this_month
# 3              23000.0             17000.0             15800.0
# 6              18900.0             17000.0             18900.0
# 2              14000.0             14800.0             18600.0
# 7              21900.0             18900.0             17000.0
# 4              18000.0             18900.0             23000.0
# 5              16500.0             17300.0             21000.0

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 0.59309608, -0.94895216,  0.1056035 ])

# %%
lr.predict(X_test)
# Out:
# array([18143.37875054, 17390.54530065])

# %%
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 6524360.346376337

# %%
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 212067.4632944575
